# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In following examples of multivariate analysis, superscript i denotes the ith training example from 1 to m training examples and j denotes the jth feature from 1 to n

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# option 3 is incorrect because sum should start at 0 incorporating the bias term theta0 and x0=1
#
# option 4 in incorrect because the label term y doesn't require subscript j as it is a single feature

# %% [markdown]
# ![Screenshot 2024-10-04 064646.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can speed up gradient descent by having each of our input values in roughly the same range. This is because θ will descend quickly on small ranges and slowly on large ranges, and so will oscillate inefficiently down to the optimum when the variables are very uneven.
#
# The way to prevent this is to modify the ranges of our input variables so that they are all roughly the same. Ideally:
#
# -1 ≤ x(i) ​≤ 1
#
# or
#
# -0.5 ≤ x(i) ​≤ 0.5
#
# These aren't exact requirements; we are only trying to speed things up. The goal is to get all input variables into roughly one of these ranges, give or take a few.
#
# Two techniques to help with this are feature scaling and mean normalization. Feature scaling involves dividing the input values by the range (i.e. the maximum value minus the minimum value) of the input variable, resulting in a new range of just 1. Mean normalization involves subtracting the average value for an input variable from the values for that input variable resulting in a new average value for the input variable of just zero. To implement both of these techniques, adjust your input values as shown in this formula:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To summarize:
#
#  If α is too small: slow convergence.
#
#  If α is too large: may not decrease on every iteration and thus may not converge.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can make use of polynomial model to fit linear regression as we can assign the degreed coefficients of the polynomial equation to linear coefficient. for example if we are given area of the house and we feel area^2 and area^3 are also required but it won't be possible with linear regression then we can assign the area degrees to simple coefficients which can be model under linear regression. so x1= area, x2 = area^2, x3 = area^3 so that y = a0 + a1.x1 + a2.x2 + a3.x3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
